# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import logging, sys
logging.disable(sys.maxsize)
import warnings
warnings.filterwarnings('ignore')
import psycopg2.extras
from apps.doge.doge_utils import *
import time

committees = load_committees_in_period(ticker='BTC_USDT', exchange='binance', start_timestamp=0, end_timestamp=time.time())
print(f'Loaded {len(committees)} committees.')
# Out:
# Loaded 23 committees.

# %%
for committee in committees:
    print(f'Commitee {committee.time_str}')
    committee.show_all_traders()
# Out:
# Commitee 2019/03/08 15:20:00 UTC
# Commitee 2019/03/08 17:40:00 UTC
# Commitee 2019/03/08 19:50:00 UTC
# Commitee 2019/03/08 21:55:00 UTC
# Commitee 2019/03/09 00:05:00 UTC
# Commitee 2019/03/11 08:50:00 UTC
# Commitee 2019/03/11 11:00:00 UTC
# Commitee 2019/03/11 13:10:00 UTC
# Commitee 2019/03/11 16:30:00 UTC
# Commitee 2019/03/11 19:55:00 UTC
# Commitee 2019/03/12 00:10:00 UTC
# Commitee 2019/03/12 05:25:00 UTC
# Commitee 2019/03/12 08:15:00 UTC
# Commitee 2019/03/12 11:40:00 UTC
# Commitee 2019/03/12 15:15:00 UTC
# Commitee 2019/03/12 19:00:00 UTC
# Commitee 2019/03/12 21:10:00 UTC
# Commitee 2019/03/15 12:55:00 UTC
# Commitee 2019/03/15 15:25:00 UTC
# Commitee 2019/03/15 20:05:00 UTC
# Commitee 2019/03/15 23:40:00 UTC
# Commitee 2019/03/16 04:15:00 UTC
# Commitee 2019/03/16 08:55:00 UTC

# %%
from apps.doge.doge_utils import backtest, committees_report
ticker = 'BTC_USDT'
end = db_interface.get_nearest_db_timestamp(time.time(), ticker, exchange="binance")
start = db_interface.get_nearest_db_timestamp(end-60*60*24, ticker, exchange="binance")
committees_report(ticker, 'binance', start, end)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4eeded17369e> in <module>()
#       1 from apps.doge.doge_utils import backtest, committees_report
#       2 ticker = 'BTC_USDT'
# ----> 3 end = db_interface.get_nearest_db_timestamp(time.time(), ticker, exchange="binance")
#       4 start = db_interface.get_nearest_db_timestamp(end-60*60*24, ticker, exchange="binance")
#       5 committees_report(ticker, 'binance', start, end)
#
# NameError: name 'db_interface' is not defined

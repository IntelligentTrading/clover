# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from apps.doge.doge_utils import *
# Out:
# INFO:settings:Deployment environment detected: LOCAL
# INFO:settings:LOCAL environment detected. Importing local_settings.py
# INFO:redis_db:Redis connection established for app database.
# INFO:redis_db:Redis currently consumes 56.18% out of 39.20G
# DEBUG:matplotlib:$HOME=/Users/karla
# DEBUG:matplotlib:matplotlib data path /Users/karla/Envs/ITF/lib/python3.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /Users/karla/.matplotlib/matplotlibrc
# DEBUG:matplotlib:matplotlib version 2.2.3
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is darwin
# ...

# %%
import time
committees = load_committees_in_period(ticker='BTC_USDT', exchange='binance', start_timestamp=0, end_timestamp=time.time())
# Out:
# INFO:root:Loaded 101 committees.

# %%
from apps.doge.doge_utils import backtest, committees_report
ticker = 'BTC_USDT'
end = db_interface.get_nearest_db_timestamp(time.time(), ticker, exchange="binance")
start = db_interface.get_nearest_db_timestamp(end-60*60*24, ticker, exchange="binance")
committees_report(ticker, 'binance', start, end)
# Out:
# INFO:root:Loaded 14 committees.
# INFO:root: >>>>>>>> Building a data object for BTC_USDT...
# CRITICAL:root:Encountered duplicate values in price data data, 320 values loaded, 287 remain after removal.
# INFO:root:Retrieving values for rsi
# INFO:root:Going to Redis for indicator rsi for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for sma20
# INFO:root:Going to Redis for indicator sma20 for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for sma50
# INFO:root:Going to Redis for indicator sma50 for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for sma200
# INFO:root:Going to Redis for indicator sma200 for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for ema20
# INFO:root:Going to Redis for indicator ema20 for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for ema50
# INFO:root:Going to Redis for indicator ema50 for BTC_USDT at 1549030500...
# INFO:root:Retrieving values for ema200
# ...
